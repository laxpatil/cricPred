# %%
import graphlab as gl
# Out:
# A newer version of GraphLab Create (v1.8.5) is available! Your current version is v1.7.1.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %%
data= gl.SFrame("../Instantaneous features/batsmanToBeClustered.csv")
# Out:
# [INFO] 1459723249 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to /home/laxmikant/anaconda/lib/python2.7/site-packages/certifi/cacert.pem
# 1459723249 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to Laxmikant.Patil@asu.edu and will expire on December 05, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-3065 - Server binary: /home/laxmikant/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1459723249.log
# [INFO] GraphLab Server Version: 1.7.1
# PROGRESS: Finished parsing file /home/laxmikant/cricPred/Instantaneous features/batsmanToBeClustered.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.027917 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,float,float,float,float,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /home/laxmikant/cricPred/Instantaneous features/batsmanToBeClustered.csv
# PROGRESS: Parsing completed. Parsed 576 lines in 0.009014 secs.

# %%
data
# Out:
# Columns:
# 	Batsman	str
# 	Home Run Hitting Ability	float
# 	Milestone Reaching Ability	float
# 	Batting Average	float
# 	Strike Rate	float
# 	Matches Played	int
#
# Rows: 576
#
# Data:
# +-------------+--------------------------+----------------------------+
# |   Batsman   | Home Run Hitting Ability | Milestone Reaching Ability |
# +-------------+--------------------------+----------------------------+
# |  JA Morkel  |      2.42424242424       |      0.0606060606061       |
# |   HH Gibbs  |      4.61538461538       |       0.307692307692       |
# |  T Thushara |       1.7619047619       |       0.047619047619       |
# |   V Sehwag  |      5.88636363636       |       0.238636363636       |
# |  KA Edwards |          1.875           |           0.0625           |
# | SC Williams |      2.56923076923       |       0.276923076923       |
# |  DE Bernard |           1.0            |            0.0             |
# | WK McCallan |      0.692307692308      |            0.0             |
# | LE Plunkett |      1.38095238095       |            0.0             |
# |  RK Whelan  |           0.5            |            0.0             |
# +-------------+--------------------------+----------------------------+
# +-----------------+---------------+----------------+
# | Batting Average |  Strike Rate  | Matches Played |
# +-----------------+---------------+----------------+
# |  19.9696969697  | 99.5468277946 |       33       |
# |  35.6923076923  | 83.4157303371 |       52       |
# |  16.4761904762  | 93.7669376694 |       21       |
# |  38.8295454545  | 108.648648649 |       88       |
# |     20.6875     | 64.9019607843 |       16       |
# |  28.5384615385  | 80.7926829268 |       65       |
# |       13.4      | 63.5071090047 |       10       |
# |  7.69230769231  | 56.8181818182 |       13       |
# |  13.1904761905  | 113.991769547 |       21       |
# |       2.5       | 41.6666666667 |       2        |
# +-----------------+---------------+----------------+
# [576 rows x 6 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
kmeans_model = gl.kmeans.create(data,features=['Home Run Hitting Ability', 'Milestone Reaching Ability','Batting Average','Strike Rate'], num_clusters=5)
# Out:
# PROGRESS: Initializing data.
# PROGRESS: Batch size is larger than the input dataset. Switching to an exact Kmeans method.
# PROGRESS: Choosing initial cluster centers with Kmeans++.
# PROGRESS: +---------------+-----------+
# PROGRESS: | Center number | Row index |
# PROGRESS: +---------------+-----------+
# PROGRESS: | 0             | 165       |
# PROGRESS: | 1             | 459       |
# PROGRESS: | 2             | 189       |
# PROGRESS: | 3             | 197       |
# PROGRESS: | 4             | 465       |
# PROGRESS: +---------------+-----------+
# PROGRESS: Starting kmeans model training.
# PROGRESS: Assigning points to initial cluster centers.
# PROGRESS: +-----------+-------------------------------+
# PROGRESS: | Iteration | Number of changed assignments |
# PROGRESS: +-----------+-------------------------------+
# PROGRESS: | 1         | 65                            |
# PROGRESS: | 2         | 63                            |
# PROGRESS: | 3         | 47                            |
# PROGRESS: | 4         | 32                            |
# PROGRESS: | 5         | 24                            |
# PROGRESS: | 6         | 14                            |
# PROGRESS: | 7         | 9                             |
# PROGRESS: | 8         | 11                            |
# PROGRESS: | 9         | 4                             |
# PROGRESS: | 10        | 5                             |
# PROGRESS: +-----------+-------------------------------+
# PROGRESS: WARNING: Clustering did not converge within max_iterations.

# %%
kmeans_model.summary()
# Out:
# Class                           : KmeansModel
#
# Schema
# ------
# Number of clusters              : 5
# Number of examples              : 576
# Number of feature columns       : 4
# Number of unpacked features     : 4
#
# Training Summary
# ----------------
# Training method                 : elkan
# Number of training iterations   : 10
# Batch size                      : 576
# Total training time (seconds)   : 0.0164
#
# Accessible fields               :
#    cluster_id                   : An SFrame containing the cluster assignments.
#    cluster_info                 : An SFrame containing the cluster centers.

# %%
kmeans_model['cluster_info'].print_rows(num_columns=5, max_row_width=1000,
                                        max_column_width=1000)
# Out:
# +--------------------------+----------------------------+-----------------+---------------+------------+-----+
# | Home Run Hitting Ability | Milestone Reaching Ability | Batting Average |  Strike Rate  | cluster_id | ... |
# +--------------------------+----------------------------+-----------------+---------------+------------+-----+
# |      2.18960463781       |      0.0834869580208       |   18.517146956  | 99.4715206895 |     0      | ... |
# |      1.30690739401       |      0.0339166461157       |  12.6677880904  |  71.736244096 |     1      | ... |
# |           2.2            |            0.0             |       11.9      | 187.293233083 |     2      | ... |
# |      0.791425961728      |       0.014539949074       |  8.12935401843  | 48.4750470702 |     3      | ... |
# |      3.43191897739       |       0.228093672933       |  31.4339057221  | 77.5165446884 |     4      | ... |
# +--------------------------+----------------------------+-----------------+---------------+------------+-----+
# [5 rows x 7 columns]

# %%
kresult=kmeans_model['cluster_id']

# %%
kresult
# Out:
# Columns:
# 	row_id	int
# 	cluster_id	int
# 	distance	float
#
# Rows: 576
#
# Data:
# +--------+------------+---------------+
# | row_id | cluster_id |    distance   |
# +--------+------------+---------------+
# |   0    |     0      |  1.4734826088 |
# |   1    |     4      | 7.37165546417 |
# |   2    |     0      | 6.07387733459 |
# |   3    |     0      | 22.5943202972 |
# |   4    |     1      | 10.5520973206 |
# |   5    |     4      | 4.45682573318 |
# |   6    |     1      | 8.26741409302 |
# |   7    |     3      | 8.35517501831 |
# |   8    |     0      | 15.4877996445 |
# |   9    |     3      | 8.83905029297 |
# +--------+------------+---------------+
# [576 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
data.num_rows
# Out:
# <bound method SFrame.num_rows of Columns:
# 	Batsman	str
# 	Home Run Hitting Ability	float
# 	Milestone Reaching Ability	float
# 	Batting Average	float
# 	Strike Rate	float
# 	Matches Played	int
#
# Rows: 576
#
# Data:
# +-------------+--------------------------+----------------------------+
# |   Batsman   | Home Run Hitting Ability | Milestone Reaching Ability |
# +-------------+--------------------------+----------------------------+
# |  JA Morkel  |      2.42424242424       |      0.0606060606061       |
# |   HH Gibbs  |      4.61538461538       |       0.307692307692       |
# |  T Thushara |       1.7619047619       |       0.047619047619       |
# |   V Sehwag  |      5.88636363636       |       0.238636363636       |
# |  KA Edwards |          1.875           |           0.0625           |
# | SC Williams |      2.56923076923       |       0.276923076923       |
# |  DE Bernard |           1.0            |            0.0             |
# | WK McCallan |      0.692307692308      |            0.0             |
# | LE Plunkett |      1.38095238095       |            0.0             |
# |  RK Whelan  |           0.5            |            0.0             |
# +-------------+--------------------------+----------------------------+
# +-----------------+---------------+----------------+
# | Batting Average |  Strike Rate  | Matches Played |
# +-----------------+---------------+----------------+
# |  19.9696969697  | 99.5468277946 |       33       |
# |  35.6923076923  | 83.4157303371 |       52       |
# |  16.4761904762  | 93.7669376694 |       21       |
# |  38.8295454545  | 108.648648649 |       88       |
# |     20.6875     | 64.9019607843 |       16       |
# |  28.5384615385  | 80.7926829268 |       65       |
# |       13.4      | 63.5071090047 |       10       |
# |  7.69230769231  | 56.8181818182 |       13       |
# |  13.1904761905  | 113.991769547 |       21       |
# |       2.5       | 41.6666666667 |       2        |
# +-----------------+---------------+----------------+
# [576 rows x 6 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.>

# %%
openFile=open("../Instantaneous features/batsmanClusters.csv", "w")
fileHeader="Batsman,Home Run Hitting Ability,Milestone Reaching Ability,Batting Average,Strike Rate,Matches Played,ClusterID"
openFile.write(fileHeader)
openFile.write("\n")

# %%
count=0
for row in kresult:
    print row['row_id']
    rowid=row['row_id']
    print data[rowid]['Batsman']
    feature="" + data[rowid]['Batsman'] + "," + str(data[rowid]['Home Run Hitting Ability']) + "," + str(data[rowid]['Milestone Reaching Ability']) + ","  + str(data[rowid]['Batting Average']) + "," +  str(data[rowid]['Strike Rate']) + ","+ str(data[rowid]['Matches Played']) + "," + str(row['cluster_id'])
    print feature
    count=count+1
    openFile.write(feature)
    openFile.write("\n")
# Out:
# 0
# JA Morkel
# JA Morkel,2.42424242424,0.0606060606061,19.9696969697,99.5468277946,33,0
# 1
# HH Gibbs
# HH Gibbs,4.61538461538,0.307692307692,35.6923076923,83.4157303371,52,4
# 2
# T Thushara
# T Thushara,1.7619047619,0.047619047619,16.4761904762,93.7669376694,21,0
# 3
# V Sehwag
# V Sehwag,5.88636363636,0.238636363636,38.8295454545,108.648648649,88,0
# 4
# KA Edwards
# KA Edwards,1.875,0.0625,20.6875,64.9019607843,16,1
# 5
# SC Williams
# SC Williams,2.56923076923,0.276923076923,28.5384615385,80.7926829268,65,4
# 6
# DE Bernard
# DE Bernard,1.0,0.0,13.4,63.5071090047,10,1
# 7
# WK McCallan
# WK McCallan,0.692307692308,0.0,7.69230769231,56.8181818182,13,3
# 8
# LE Plunkett
# LE Plunkett,1.38095238095,0.0,13.1904761905,113.991769547,21,0
# 9
# RK Whelan
# RK Whelan,0.5,0.0,2.5,41.6666666667,2,3
# 10
# MJ Guptill
# MJ Guptill,4.80869565217,0.313043478261,38.1217391304,82.7482068705,115,4
# 11
# GB Hogg
# GB Hogg,0.769230769231,0.0,13.6923076923,69.53125,13,1
# 12
# CT Tremlett
# CT Tremlett,0.4,0.0,4.2,57.5342465753,10,3
# 13
# JW Hastings
# JW Hastings,1.76923076923,0.0,13.8461538462,95.2380952381,13,0
# 14
# PA Hitchcock
# PA Hitchcock,1.0,0.0,10.0,90.9090909091,1,0
# 15
# CK Kapugedera
# CK Kapugedera,1.74137931034,0.120689655172,21.1379310345,68.6066032457,58,1
# 16
# N Deonarine
# N Deonarine,2.09090909091,0.136363636364,20.9545454545,65.7631954351,22,1
# 17
# CR Brathwaite
# CR Brathwaite,1.14285714286,0.0,10.1428571429,81.6091954023,7,1
# 18
# MC Sorensen
# MC Sorensen,2.0,0.0,15.75,84.0,4,1
# 19
# ML Udawatte
# ML Udawatte,2.33333333333,0.0,17.1666666667,62.0481927711,6,1
# 20
# NW Bracken
# NW Bracken,0.391304347826,0.0,4.91304347826,62.4309392265,23,1
# 21
# Rajin Saleh
# Rajin Saleh,3.5,0.0,21.5,53.0864197531,2,3
# 22
# SR Patel
# SR Patel,2.22727272727,0.0454545454545,21.9090909091,90.6015037594,22,0
# 23
# M Kartik
# M Kartik,1.66666666667,0.0,12.3333333333,75.5102040816,3,1
# 24
# Rubel Hossain
# Rubel Hossain,0.32,0.0,2.68,52.34375,25,3
# 25
# Ziaur Rahman
# Ziaur Rahman,1.2,0.0,8.3,91.2087912088,10,0
# 26
# CK Coventry
# CK Coventry,3.33333333333,0.166666666667,29.3888888889,90.2730375427,18,4
# 27
# TA Boult
# TA Boult,0.727272727273,0.0,5.27272727273,77.3333333333,11,1
# 28
# D Mongia
# D Mongia,2.5,0.166666666667,26.1666666667,60.153256705,6,1
# 29
# D Ganga
# D Ganga,1.0,0.0,20.5,39.0476190476,2,3
# 30
# MJ Santner
# MJ Santner,3.0,0.0,26.7272727273,102.083333333,11,0
# 31
# CT Mutombodzi
# CT Mutombodzi,0.666666666667,0.0,10.6666666667,72.7272727273,3,1
# 32
# CR Ervine
# CR Ervine,3.06666666667,0.2,30.5333333333,73.9903069467,30,4
# 33
# XM Marshall
# XM Marshall,1.5,0.0,10.5,58.3333333333,8,3
# 34
# IR Bell
# IR Bell,3.63432835821,0.246268656716,35.3805970149,75.6623045005,134,4
# 35
# RV Uthappa
# RV Uthappa,3.0,0.117647058824,22.1470588235,89.0070921986,34,0
# 36
# J Nyumbu
# J Nyumbu,0.153846153846,0.0,3.46153846154,50.0,13,3
# 37
# KW Richardson
# KW Richardson,1.0,0.0,7.5,157.894736842,4,2
# 38
# Umar Gul
# Umar Gul,0.771929824561,0.0,7.14035087719,68.288590604,57,1
# 39
# HDRL Thirimanne
# HDRL Thirimanne,2.77777777778,0.246913580247,31.5802469136,71.4724783459,81,4
# 40
# D Elgar
# D Elgar,1.0,0.0,19.6,60.4938271605,5,1
# 41
# Abdur Rehman
# Abdur Rehman,0.52380952381,0.0,6.04761904762,55.701754386,21,3
# 42
# H Masakadza
# H Masakadza,3.11214953271,0.18691588785,26.9719626168,70.0485436893,107,4
# 43
# KO Meth
# KO Meth,0.8,0.0,6.4,61.5384615385,5,1
# 44
# B Lee
# B Lee,1.09090909091,0.0227272727273,10.8181818182,81.5068493151,44,1
# 45
# JR Hazlewood
# JR Hazlewood,0.5,0.0,2.5,55.5555555556,2,3
# 46
# R Mutumbami
# R Mutumbami,1.93333333333,0.0666666666667,15.4666666667,69.8795180723,15,1
# 47
# PP Ojha
# PP Ojha,0.333333333333,0.0,5.11111111111,40.350877193,9,3
# 48
# TWM Latham
# TWM Latham,2.76470588235,0.147058823529,25.3529411765,75.2181500873,34,4
# 49
# JH Kallis
# JH Kallis,3.58620689655,0.35632183908,37.2643678161,76.4442348503,87,4
# 50
# MM Patel
# MM Patel,0.363636363636,0.0,3.22727272727,66.9811320755,22,1
# 51
# DE Bollinger
# DE Bollinger,0.714285714286,0.0,7.14285714286,92.5925925926,7,0
# 52
# LRPL Taylor
# LRPL Taylor,3.68382352941,0.301470588235,36.7205882353,79.3958664547,136,4
# 53
# CH Gayle
# CH Gayle,4.58620689655,0.206896551724,31.1293103448,89.4254581476,116,4
# 54
# PC de Silva
# PC de Silva,1.4,0.0,12.4,73.8095238095,5,1
# 55
# NM Hauritz
# NM Hauritz,1.04,0.04,11.64,93.5691318328,25,0
# 56
# MDKJ Perera
# MDKJ Perera,3.30434782609,0.195652173913,25.7391304348,90.5198776758,46,0
# 57
# SP Narine
# SP Narine,1.05882352941,0.0,8.55882352941,76.3779527559,34,1
# 58
# SJ Benn
# SJ Benn,0.8,0.0,6.75,72.972972973,20,1
# 59
# IJL Trott
# IJL Trott,3.38709677419,0.403225806452,43.7903225806,75.2494456763,62,4
# 60
# BAW Mendis
# BAW Mendis,0.447368421053,0.0,4.47368421053,66.40625,38,1
# 61
# PD McGlashan
# PD McGlashan,3.5,0.5,30.5,115.094339623,2,0
# 62
# IK Pathan
# IK Pathan,1.875,0.025,16.85,78.281068525,40,1
# 63
# CJ Anderson
# CJ Anderson,3.90909090909,0.151515151515,30.2424242424,112.514092446,33,0
# 64
# Khaled Mashud
# Khaled Mashud,0.333333333333,0.0,13.6666666667,43.1578947368,3,3
# 65
# Hammad Azam
# Hammad Azam,1.4,0.0,14.8,62.1848739496,5,1
# 66
# L Balaji
# L Balaji,1.0,0.0,7.0,70.0,1,1
# 67
# PG Fulton
# PG Fulton,2.75,0.1875,27.40625,67.4615384615,32,4
# 68
# ST Finn
# ST Finn,0.583333333333,0.0,5.41666666667,59.6330275229,24,3
# 69
# SL Malinga
# SL Malinga,0.617283950617,0.0123456790123,4.97530864198,74.6296296296,81,1
# 70
# PC Connell
# PC Connell,1.0,0.0,6.0,26.0869565217,1,3
# 71
# LM Jongwe
# LM Jongwe,1.09090909091,0.0,11.0,65.7608695652,11,1
# 72
# RR Emrit
# RR Emrit,0.5,0.0,6.5,37.1428571429,2,3
# 73
# KOA Powell
# KOA Powell,3.59259259259,0.222222222222,26.4814814815,80.6087936866,27,4
# 74
# Abdur Razzak
# Abdur Razzak,0.849315068493,0.013698630137,8.39726027397,73.8554216867,73,1
# 75
# Mahmudullah
# Mahmudullah,2.26530612245,0.15306122449,24.4285714286,70.9543568465,98,4
# 76
# ND McKenzie
# ND McKenzie,2.25,0.25,27.0,64.2857142857,4,4
# 77
# JR Hopes
# JR Hopes,2.09259259259,0.0555555555556,21.2777777778,91.4808917197,54,0
# 78
# T Maruma
# T Maruma,0.5,0.0,5.5,38.3720930233,12,3
# 79
# HF Gurney
# HF Gurney,0.166666666667,0.0,2.5,45.4545454545,6,3
# 80
# E Chigumbura
# E Chigumbura,2.28947368421,0.114035087719,22.7894736842,77.7844311377,114,4
# 81
# KP Pietersen
# KP Pietersen,3.69892473118,0.236559139785,33.4946236559,82.2116653471,93,4
# 82
# VD Philander
# VD Philander,0.8125,0.0,8.8125,66.5094339623,16,1
# 83
# CJ Ferguson
# CJ Ferguson,2.47826086957,0.173913043478,26.347826087,80.4780876494,23,4
# 84
# DL Vettori
# DL Vettori,1.43661971831,0.0281690140845,15.7605633803,86.0107609531,71,0
# 85
# Shahzaib Hasan
# Shahzaib Hasan,5.0,0.333333333333,33.3333333333,84.7457627119,3,4
# 86
# GW Flower
# GW Flower,1.0,0.0,17.5,76.0869565217,2,1
# 87
# Syed Rasel
# Syed Rasel,0.222222222222,0.0,2.88888888889,37.6811594203,18,3
# 88
# Ahmed Shehzad
# Ahmed Shehzad,3.67142857143,0.242857142857,33.2714285714,70.8117968988,70,4
# 89
# MT Chinouya
# MT Chinouya,0.5,0.0,3.0,66.6666666667,2,1
# 90
# JDS Neesham
# JDS Neesham,1.75,0.0,14.875,93.7007874016,16,0
# 91
# CAK Walton
# CAK Walton,0.25,0.0,4.25,56.6666666667,4,3
# 92
# RA Jadeja
# RA Jadeja,2.12941176471,0.117647058824,21.7529411765,82.4342398573,85,4
# 93
# LD Chandimal
# LD Chandimal,2.1847826087,0.184782608696,25.7391304348,73.8615096694,92,4
# 94
# BMAJ Mendis
# BMAJ Mendis,1.43243243243,0.027027027027,15.1621621622,82.8655834564,37,1
# 95
# SMA Priyanjan
# SMA Priyanjan,2.5,0.1,20.95,78.6116322702,20,4
# 96
# JP Duminy
# JP Duminy,2.32520325203,0.186991869919,29.9674796748,80.2350892468,123,4
# 97
# LJ Woodcock
# LJ Woodcock,0.5,0.0,6.5,59.0909090909,2,3
# 98
# NO Miller
# NO Miller,1.0,0.0416666666667,10.3333333333,79.2332268371,24,1
# 99
# Jahurul Islam
# Jahurul Islam,2.18181818182,0.0909090909091,20.5454545455,69.5384615385,11,1
# 100
# DJ Hussey
# DJ Hussey,2.54385964912,0.245614035088,29.2105263158,87.8627968338,57,4
# 101
# MG Johnson
# MG Johnson,1.18518518519,0.0246913580247,10.7901234568,94.1810344828,81,0
# 102
# Zulqarnain Haider
# Zulqarnain Haider,0.75,0.0,11.75,67.1428571429,4,1
# 103
# SM Pollock
# SM Pollock,1.58620689655,0.0689655172414,16.9310344828,82.3825503356,29,1
# 104
# PD Collingwood
# PD Collingwood,2.62365591398,0.193548387097,30.5161290323,76.8064952639,93,4
# 105
# CH Morris
# CH Morris,1.83333333333,0.166666666667,16.0,101.052631579,6,0
# 106
# Asad Shafiq
# Asad Shafiq,2.07843137255,0.176470588235,24.7843137255,67.1269251195,51,4
# 107
# Bazid Khan
# Bazid Khan,1.5,0.5,26.0,50.9803921569,2,3
# 108
# PJ Forrest
# PJ Forrest,2.71428571429,0.285714285714,26.2142857143,63.6048526863,14,4
# 109
# AJ Hall
# AJ Hall,1.4,0.1,14.4,87.8048780488,10,0
# 110
# Sikandar Raza
# Sikandar Raza,3.0,0.131578947368,26.1842105263,81.1582381729,38,4
# 111
# RJ Sidebottom
# RJ Sidebottom,0.6875,0.0,7.6875,65.7754010695,16,1
# 112
# AC Gilchrist
# AC Gilchrist,4.3,0.275,31.425,96.1009174312,40,0
# 113
# M Morkel
# M Morkel,0.6,0.0,5.28571428571,72.265625,35,1
# 114
# ST Jayasuriya
# ST Jayasuriya,4.91549295775,0.211267605634,33.985915493,98.4897959184,71,0
# 115
# CJ Chibhabha
# CJ Chibhabha,2.5671641791,0.149253731343,23.5373134328,64.73727422,67,1
# 116
# Tamim Iqbal
# Tamim Iqbal,4.0534351145,0.274809160305,31.8015267176,76.8067846608,131,4
# 117
# MJ Lumb
# MJ Lumb,5.0,0.333333333333,55.0,80.0970873786,3,4
# 118
# JM How
# JM How,3.34615384615,0.192307692308,29.9230769231,64.9415692821,26,4
# 119
# N Madziva
# N Madziva,0.714285714286,0.0,7.0,50.5154639175,7,3
# 120
# D Wiese
# D Wiese,2.0,0.0,17.0,86.4406779661,6,0
# 121
# Aizaz Cheema
# Aizaz Cheema,0.333333333333,0.0,4.33333333333,57.7777777778,6,3
# 122
# DR Martyn
# DR Martyn,5.71428571429,0.428571428571,44.5714285714,65.1356993737,7,4
# 123
# Sohaib Maqsood
# Sohaib Maqsood,2.86956521739,0.217391304348,29.4347826087,79.7408716137,23,4
# 124
# ADS Fletcher
# ADS Fletcher,1.8125,0.125,13.5,62.6086956522,16,1
# 125
# G Chapple
# G Chapple,2.0,0.0,13.0,185.714285714,1,2
# 126
# LE Bosman
# LE Bosman,4.18181818182,0.181818181818,27.1818181818,97.7124183007,11,0
# 127
# JWA Taylor
# JWA Taylor,3.375,0.333333333333,35.9166666667,79.8887859129,24,4
# 128
# HMCM Bandara
# HMCM Bandara,1.0,0.0,12.2857142857,80.3738317757,7,1
# 129
# LMP Simmons
# LMP Simmons,3.3125,0.28125,30.59375,71.4337832908,64,4
# 130
# DM Richards
# DM Richards,3.42857142857,0.285714285714,25.5714285714,68.8461538462,7,4
# 131
# Soumya Sarkar
# Soumya Sarkar,7.35714285714,0.357142857143,47.2857142857,99.1017964072,14,4
# 132
# RE van der Merwe
# RE van der Merwe,0.714285714286,0.0,5.57142857143,95.1219512195,7,0
# 133
# EC Joyce
# EC Joyce,3.08571428571,0.2,28.3428571429,68.6505190311,35,4
# 134
# Mushfiqur Rahim
# Mushfiqur Rahim,2.61111111111,0.18253968254,27.7777777778,75.2526338422,126,4
# 135
# Mohammad Ashraful
# Mohammad Ashraful,2.17721518987,0.113924050633,19.4556962025,63.9085239085,79,1
# 136
# Sohag Gazi
# Sohag Gazi,1.46666666667,0.0,12.1333333333,87.922705314,15,0
# 137
# AR Cusack
# AR Cusack,1.2,0.0,12.0666666667,65.1079136691,15,1
# 138
# Farhad Reza
# Farhad Reza,1.0,0.0,10.2727272727,54.3269230769,22,3
# 139
# TD Paine
# TD Paine,3.39130434783,0.217391304348,27.652173913,65.7704239917,23,4
# 140
# PJ Moor
# PJ Moor,0.5,0.0,7.5,41.6666666667,2,3
# 141
# KA Pollard
# KA Pollard,2.70512820513,0.115384615385,24.5,88.064516129,78,4
# 142
# SM Davies
# SM Davies,4.5,0.125,30.125,100.836820084,8,0
# 143
# SR Watson
# SR Watson,4.71317829457,0.286821705426,37.7906976744,90.0942524487,129,4
# 144
# NLTC Perera
# NLTC Perera,1.65333333333,0.0666666666667,14.32,105.397448479,75,0
# 145
# Gurkeerat Singh
# Gurkeerat Singh,1.0,0.0,6.5,100.0,2,0
# 146
# R McLaren
# R McLaren,1.2,0.025,11.975,69.8250728863,40,1
# 147
# KJ Abbott
# KJ Abbott,0.6,0.0,6.6,58.407079646,10,3
# 148
# VR Aaron
# VR Aaron,0.333333333333,0.0,2.66666666667,53.3333333333,3,3
# 149
# JC Buttler
# JC Buttler,3.47457627119,0.186440677966,29.9152542373,115.359477124,59,0
# 150
# KM Dabengwa
# KM Dabengwa,1.2,0.0,16.7,61.1721611722,20,1
# 151
# GC Smith
# GC Smith,3.97,0.29,33.57,79.6819368621,100,4
# 152
# A Symonds
# A Symonds,3.44186046512,0.302325581395,32.0465116279,91.561461794,43,4
# 153
# AJ Redmond
# AJ Redmond,3.16666666667,0.166666666667,25.3333333333,57.1428571429,6,3
# 154
# Inzamam-ul-Haq
# Inzamam-ul-Haq,3.16666666667,0.0,26.9166666667,70.989010989,12,4
# 155
# MEK Hussey
# MEK Hussey,2.75630252101,0.260504201681,34.0840336134,82.4893227578,119,4
# 156
# MM Ali
# MM Ali,2.67647058824,0.117647058824,21.3823529412,94.5383615085,34,0
# 157
# AM Phangiso
# AM Phangiso,0.555555555556,0.0,7.33333333333,62.2641509434,9,1
# 158
# JDP Oram
# JDP Oram,2.70833333333,0.1875,25.0416666667,95.8532695375,48,0
# 159
# MJ McClenaghan
# MJ McClenaghan,0.928571428571,0.0,7.71428571429,75.5244755245,14,1
# 160
# SS Tiwary
# SS Tiwary,3.0,0.0,24.5,85.9649122807,2,4
# 161
# NM Coulter-Nile
# NM Coulter-Nile,0.571428571429,0.0,8.57142857143,69.7674418605,7,1
# 162
# Khurram Manzoor
# Khurram Manzoor,3.33333333333,0.5,33.6666666667,62.5386996904,6,4
# 163
# DJ Bravo
# DJ Bravo,2.35514018692,0.11214953271,23.1588785047,80.9010773751,107,4
# 164
# Shamsur Rahman
# Shamsur Rahman,3.55555555556,0.222222222222,29.5555555556,74.5098039216,9,4
# 165
# BJ Hodge
# BJ Hodge,2.76923076923,0.153846153846,26.4615384615,83.9024390244,13,4
# 166
# DJ Willey
# DJ Willey,0.571428571429,0.0,8.28571428571,86.5671641791,7,1
# 167
# HM Amla
# HM Amla,5.20168067227,0.403361344538,48.7899159664,86.9291810151,119,4
# 168
# AR McBrine
# AR McBrine,1.0,0.0,11.5,93.8775510204,4,0
# 169
# B Kumar
# B Kumar,0.75,0.0,7.39285714286,72.1254355401,28,1
# 170
# GJ Bailey
# GJ Bailey,3.34920634921,0.301587301587,36.3492063492,84.6580406654,63,4
# 171
# PJ Ingram
# PJ Ingram,4.28571428571,0.142857142857,27.5714285714,80.7531380753,7,4
# 172
# JP Bray
# JP Bray,2.7,0.1,23.4,63.0727762803,10,1
# 173
# R Dravid
# R Dravid,2.83720930233,0.255813953488,29.8604651163,72.7066817667,43,4
# 174
# RP Singh
# RP Singh,0.333333333333,0.0,5.6,39.8104265403,15,3
# 175
# B Geeves
# B Geeves,1.0,0.0,10.0,90.9090909091,1,0
# 176
# SHT Kandamby
# SHT Kandamby,2.23333333333,0.166666666667,27.1666666667,69.5392491468,30,4
# 177
# SB Styris
# SB Styris,3.20754716981,0.264150943396,33.8301886792,78.7093942054,53,4
# 178
# PJK Mooney
# PJK Mooney,0.5,0.0,4.5,112.5,2,0
# 179
# Raqibul Hasan
# Raqibul Hasan,1.85106382979,0.127659574468,23.2765957447,59.2311857066,47,1
# 180
# Fawad Alam
# Fawad Alam,1.85294117647,0.176470588235,26.5588235294,72.6468222043,34,4
# 181
# Mohammad Salman
# Mohammad Salman,0.666666666667,0.0,7.33333333333,55.0,3,3
# 182
# JM Kemp
# JM Kemp,2.3,0.15,23.55,66.5254237288,20,1
# 183
# WTS Porterfield
# WTS Porterfield,2.6,0.142857142857,24.6857142857,56.2866449511,35,3
# 184
# Yuvraj Singh
# Yuvraj Singh,4.05833333333,0.258333333333,32.525,83.8093193043,120,4
# 185
# SW Billings
# SW Billings,3.0,0.0,22.5,128.571428571,4,0
# 186
# Tushar Imran
# Tushar Imran,1.0,0.0,6.75,32.1428571429,4,3
# 187
# DS Smith
# DS Smith,2.61764705882,0.147058823529,23.5588235294,71.2,34,4
# 188
# SW Masakadza
# SW Masakadza,2.0,0.0,13.625,97.3214285714,8,0
# 189
# J Louw
# J Louw,4.0,0.0,17.0,242.857142857,1,2
# 190
# MS Dhoni
# MS Dhoni,3.47872340426,0.292553191489,36.7712765957,84.1611882152,188,4
# 191
# AC Voges
# AC Voges,2.29166666667,0.125,29.625,84.1420118343,24,4
# 192
# AJ Strauss
# AJ Strauss,3.93243243243,0.27027027027,33.9054054054,79.8027989822,74,4
# 193
# GO Jones
# GO Jones,1.5,0.0,15.5,110.714285714,6,0
# 194
# A Shahzad
# A Shahzad,0.375,0.0,4.875,62.9032258065,8,1
# 195
# S Prasanna
# S Prasanna,1.25,0.0,9.5,78.8381742739,20,1
# 196
# SCJ Broad
# SCJ Broad,0.725806451613,0.0,8.04838709677,74.0356083086,62,1
# 197
# Danish Kaneria
# Danish Kaneria,1.0,0.0,2.0,50.0,1,3
# 198
# Saad Nasim
# Saad Nasim,3.33333333333,0.333333333333,33.0,79.2,3,4
# 199
# NJ O'Brien
# NJ O'Brien,2.55882352941,0.176470588235,25.5882352941,69.3779904306,34,4
# 200
# HMRKB Herath
# HMRKB Herath,0.444444444444,0.0,5.18518518519,61.6740088106,27,1
# 201
# A Balbirnie
# A Balbirnie,3.0,0.222222222222,28.7777777778,81.1912225705,9,4
# 202
# BA Parchment
# BA Parchment,2.33333333333,0.0,17.8333333333,54.0404040404,6,3
# 203
# Mohammad Yousuf
# Mohammad Yousuf,3.27586206897,0.275862068966,36.7931034483,73.9175614825,58,4
# 204
# Z Khan
# Z Khan,0.974358974359,0.0,8.35897435897,60.9345794393,39,1
# 205
# SE Bond
# SE Bond,0.5,0.0,7.0,71.7948717949,20,1
# 206
# Shahadat Hossain
# Shahadat Hossain,0.375,0.0,3.5625,50.4424778761,16,3
# 207
# SR Thompson
# SR Thompson,1.16666666667,0.0,12.0,88.8888888889,6,0
# 208
# ML Nkala
# ML Nkala,1.0,0.0,7.0,53.8461538462,2,3
# 209
# Sharjeel Khan
# Sharjeel Khan,2.6,0.1,16.9,81.25,10,1
# 210
# AD Russell
# AD Russell,3.38095238095,0.0952380952381,23.2857142857,129.536423841,42,0
# 211
# DT Tiripano
# DT Tiripano,0.75,0.0,5.75,56.0975609756,4,3
# 212
# Babar Azam
# Babar Azam,4.375,0.5,40.125,88.91966759,8,4
# 213
# SW Tait
# SW Tait,0.666666666667,0.0,4.16666666667,86.2068965517,6,1
# 214
# R Ashwin
# R Ashwin,1.16363636364,0.0181818181818,11.9454545455,84.7741935484,55,1
# 215
# DT Christian
# DT Christian,1.44444444444,0.0,15.1111111111,86.9009584665,18,0
# 216
# PR Stirling
# PR Stirling,3.47826086957,0.173913043478,24.2173913043,88.1329113924,23,0
# 217
# CL White
# CL White,2.66176470588,0.191176470588,28.8235294118,80.1308258381,68,4
# 218
# KM Jadhav
# KM Jadhav,4.5,0.25,36.25,103.571428571,4,0
# 219
# YK Pathan
# YK Pathan,2.575,0.125,19.975,110.055096419,40,0
# 220
# Imran Nazir
# Imran Nazir,4.66666666667,0.133333333333,29.0,96.0264900662,15,0
# 221
# Imran Farhat
# Imran Farhat,3.03333333333,0.266666666667,27.0333333333,62.9658385093,30,4
# 222
# CMW Read
# CMW Read,1.0,0.0,10.0,80.0,6,1
# 223
# AM Rahane
# AM Rahane,3.55737704918,0.262295081967,32.2295081967,78.0158730159,61,4
# 224
# F Mutizwa
# F Mutizwa,1.0,0.111111111111,16.1111111111,57.3122529644,9,3
# 225
# AU Rashid
# AU Rashid,2.41176470588,0.0588235294118,17.2941176471,108.888888889,17,0
# 226
# Khalid Latif
# Khalid Latif,2.6,0.2,29.4,63.0901287554,5,4
# 227
# Mashrafe Mortaza
# Mashrafe Mortaza,1.27536231884,0.0,11.1594202899,76.9230769231,69,1
# 228
# CD McMillan
# CD McMillan,3.8125,0.1875,29.75,83.950617284,16,4
# 229
# MJ Henry
# MJ Henry,1.33333333333,0.0,9.55555555556,103.614457831,9,0
# 230
# GB Brent
# GB Brent,0.75,0.0625,10.5,61.5384615385,16,1
# 231
# MA Wood
# MA Wood,1.0,0.0,8.33333333333,86.2068965517,3,1
# 232
# M Vijay
# M Vijay,2.25,0.0625,21.1875,65.6976744186,16,1
# 233
# DP Hyatt
# DP Hyatt,1.55555555556,0.0,12.4444444444,59.2592592593,9,3
# 234
# PM Siddle
# PM Siddle,0.25,0.0,4.25,94.4444444444,4,0
# 235
# MD Gunathilaka
# MD Gunathilaka,3.6,0.2,23.4,83.5714285714,5,4
# 236
# Sohail Tanvir
# Sohail Tanvir,1.18918918919,0.0,9.08108108108,81.5533980583,37,1
# 237
# JL Denly
# JL Denly,3.55555555556,0.222222222222,29.3333333333,63.1578947368,9,4
# 238
# AP Devcich
# AP Devcich,3.125,0.125,22.125,73.4439834025,8,1
# 239
# DI Joyce
# DI Joyce,1.33333333333,0.0,9.66666666667,47.5409836066,3,3
# 240
# V Sibanda
# V Sibanda,2.9696969697,0.181818181818,23.5151515152,63.5544635545,66,1
# 241
# Aftab Ahmed
# Aftab Ahmed,2.44117647059,0.0882352941176,19.1470588235,73.8095238095,34,1
# 242
# SG Borthwick
# SG Borthwick,1.0,0.0,9.0,112.5,2,0
# 243
# C Kieswetter
# C Kieswetter,3.43243243243,0.135135135135,26.4324324324,88.0288028803,37,4
# 244
# Abdul Razzaq
# Abdul Razzaq,2.225,0.075,20.475,82.0641282565,40,4
# 245
# Nazimuddin
# Nazimuddin,2.0,0.0,14.5,62.2317596567,10,1
# 246
# DR Tuffey
# DR Tuffey,1.33333333333,0.0,12.3333333333,112.977099237,12,0
# 247
# Mohammad Irfan
# Mohammad Irfan,0.233333333333,0.0,1.56666666667,30.9210526316,30,3
# 248
# Alok Kapali
# Alok Kapali,2.38461538462,0.0769230769231,20.7692307692,76.2711864407,13,1
# 249
# DM Bravo
# DM Bravo,3.0,0.226666666667,28.52,67.4550614948,75,4
# 250
# MS Sinclair
# MS Sinclair,2.4,0.2,24.4,91.7293233083,5,0
# 251
# Mohammad Hafeez
# Mohammad Hafeez,4.04511278195,0.255639097744,34.3533834586,78.0625320349,133,4
# 252
# HD Rutherford
# HD Rutherford,0.5,0.0,3.5,25.0,4,3
# 253
# JL Pattinson
# JL Pattinson,0.285714285714,0.0,5.85714285714,51.25,7,3
# 254
# Mohammad Rizwan
# Mohammad Rizwan,2.76923076923,0.230769230769,26.7692307692,92.8,13,0
# 255
# GH Bodi
# GH Bodi,5.0,0.5,41.5,61.0294117647,2,4
# 256
# S Matsikenyeri
# S Matsikenyeri,2.0,0.106382978723,19.9787234043,75.7869249395,47,1
# 257
# PP Chawla
# PP Chawla,0.25,0.0,3.16666666667,63.3333333333,12,1
# 258
# CS Baugh
# CS Baugh,1.04545454545,0.0,14.0,60.9900990099,22,1
# 259
# RP Arnold
# RP Arnold,1.14285714286,0.142857142857,16.4285714286,73.2484076433,14,1
# 260
# S Dhawan
# S Dhawan,5.65217391304,0.36231884058,43.2173913043,88.908765653,69,4
# 261
# RMS Eranga
# RMS Eranga,0.444444444444,0.0,3.77777777778,51.5151515152,9,3
# 262
# JM Bairstow
# JM Bairstow,3.0,0.1,25.9,91.1971830986,10,0
# 263
# Mithun Ali
# Mithun Ali,5.0,0.0,26.0,60.4651162791,1,1
# 264
# TS Nethula
# TS Nethula,0.333333333333,0.0,4.0,109.090909091,3,0
# 265
# PVD Chameera
# PVD Chameera,0.5,0.0,6.0,51.0638297872,4,3
# 266
# RR Powar
# RR Powar,0.333333333333,0.0,5.77777777778,51.4851485149,9,3
# 267
# TG Southee
# TG Southee,0.764705882353,0.0,7.03921568627,92.7648578811,51,0
# 268
# SE Marsh
# SE Marsh,3.66666666667,0.291666666667,35.5416666667,74.7917580009,48,4
# 269
# BRM Taylor
# BRM Taylor,3.3,0.26,33.56,76.3421292084,100,4
# 270
# CA Ingram
# CA Ingram,3.0,0.178571428571,27.1785714286,81.3903743316,28,4
# 271
# SC Ganguly
# SC Ganguly,4.56,0.36,36.8,68.299925761,25,4
# 272
# TM Dowlin
# TM Dowlin,2.1,0.2,22.7,62.7071823204,10,1
# 273
# MV Boucher
# MV Boucher,2.21052631579,0.0877192982456,22.2280701754,89.3511988717,57,0
# 274
# Kamran Hussain
# Kamran Hussain,2.0,0.0,27.0,128.571428571,1,0
# 275
# GC Tonge
# GC Tonge,0.333333333333,0.0,3.0,56.25,3,3
# 276
# AD Mathews
# AD Mathews,2.64122137405,0.198473282443,28.679389313,82.3361823362,131,4
# 277
# T Duffin
# T Duffin,4.0,0.25,35.75,62.1739130435,4,4
# 278
# NT Broom
# NT Broom,1.42105263158,0.0526315789474,16.2631578947,65.7446808511,19,1
# 279
# Junaid Khan
# Junaid Khan,0.210526315789,0.0,2.84210526316,47.7876106195,19,3
# 280
# JA Burns
# JA Burns,2.83333333333,0.166666666667,24.3333333333,77.2486772487,6,4
# 281
# MDK Perera
# MDK Perera,1.0,0.0,11.0,54.3209876543,4,3
# 282
# C de Grandhomme
# C de Grandhomme,4.0,0.0,36.0,92.3076923077,1,4
# 283
# Mominul Haque
# Mominul Haque,2.57142857143,0.0952380952381,23.3333333333,73.4632683658,21,4
# 284
# Yasir Shah
# Yasir Shah,1.16666666667,0.0,12.6666666667,91.5662650602,6,0
# 285
# TL Best
# TL Best,0.375,0.0,4.0,42.6666666667,8,3
# 286
# R Vinay Kumar
# R Vinay Kumar,0.636363636364,0.0,7.72727272727,57.0469798658,11,3
# 287
# J Blackwood
# J Blackwood,0.5,0.0,5.5,44.0,2,3
# 288
# GH Worker
# GH Worker,2.0,0.0,20.5,62.1212121212,2,1
# 289
# GC Wilson
# GC Wilson,2.22727272727,0.227272727273,22.0,78.1906300485,22,4
# 290
# MK Tiwary
# MK Tiwary,2.7,0.2,28.2,72.3076923077,10,4
# 291
# Iftikhar Anjum
# Iftikhar Anjum,0.666666666667,0.0,7.33333333333,58.7786259542,21,3
# 292
# Bilawal Bhatti
# Bilawal Bhatti,1.71428571429,0.0,12.5714285714,114.285714286,7,0
# 293
# Bilal Asif
# Bilal Asif,2.33333333333,0.0,13.3333333333,76.9230769231,3,1
# 294
# D Bishoo
# D Bishoo,0.285714285714,0.0,1.42857142857,37.037037037,7,3
# 295
# SI Mahmood
# SI Mahmood,0.888888888889,0.0,7.11111111111,81.0126582278,9,1
# 296
# TV Mufambisi
# TV Mufambisi,1.5,0.0,11.25,63.3802816901,4,1
# 297
# Mehrab Hossain jnr
# Mehrab Hossain jnr,1.7,0.1,18.3,42.4593967517,10,3
# 298
# MR Gillespie
# MR Gillespie,0.9,0.0,8.0,84.2105263158,10,1
# 299
# Saeed Ajmal
# Saeed Ajmal,0.34375,0.0,4.609375,58.3003952569,64,3
# 300
# N Mushangwe
# N Mushangwe,1.25,0.0,9.5,86.3636363636,4,1
# 301
# RW Chakabva
# RW Chakabva,0.846153846154,0.0,13.2692307692,51.3392857143,26,3
# 302
# Mohammad Rafique
# Mohammad Rafique,0.5,0.0,8.16666666667,63.2258064516,12,1
# 303
# S Chanderpaul
# S Chanderpaul,3.57142857143,0.396825396825,40.8253968254,68.0783483325,63,4
# 304
# DA Warner
# DA Warner,4.203125,0.265625,35.203125,87.7336448598,64,4
# 305
# FL Reifer
# FL Reifer,1.16666666667,0.0,14.3333333333,45.2631578947,6,3
# 306
# J Mubarak
# J Mubarak,1.21428571429,0.0714285714286,19.6428571429,69.7969543147,14,1
# 307
# TAM Siriwardana
# TAM Siriwardana,3.1,0.2,26.2,111.489361702,10,0
# 308
# EJG Morgan
# EJG Morgan,3.1954887218,0.233082706767,30.0526315789,86.9290996085,133,4
# 309
# SL Stewart
# SL Stewart,0.5,0.0,6.5,44.0677966102,4,3
# 310
# KC Sangakkara
# KC Sangakkara,4.33658536585,0.360975609756,41.9853658537,80.6276346604,205,4
# 311
# Fawad Ahmed
# Fawad Ahmed,1.0,0.0,4.0,200.0,1,2
# 312
# AT Rayudu
# AT Rayudu,3.38461538462,0.269230769231,35.6923076923,76.0655737705,26,4
# 313
# SR Tendulkar
# SR Tendulkar,5.89772727273,0.363636363636,45.6022727273,84.5376026964,88,4
# 314
# RK Kleinveldt
# RK Kleinveldt,2.0,0.0,15.0,81.3953488372,7,1
# 315
# AD Mascarenhas
# AD Mascarenhas,1.83333333333,0.0833333333333,18.5,89.5161290323,12,0
# 316
# KED Carroll
# KED Carroll,0.333333333333,0.0,9.33333333333,66.6666666667,3,1
# 317
# BCJ Cutting
# BCJ Cutting,2.5,0.0,26.5,79.1044776119,2,4
# 318
# CD Collymore
# CD Collymore,0.333333333333,0.0,3.22222222222,59.1836734694,9,3
# 319
# Mustafizur Rahman
# Mustafizur Rahman,0.5,0.0,3.75,44.1176470588,4,3
# 320
# L Vincent
# L Vincent,3.125,0.25,27.8125,67.5265553869,16,4
# 321
# T Mupariwa
# T Mupariwa,0.416666666667,0.0,3.58333333333,39.0909090909,12,3
# 322
# DSNFG Jayasuriya
# DSNFG Jayasuriya,1.0,0.0,5.5,64.7058823529,2,1
# 323
# T Panyangara
# T Panyangara,0.6,0.0,4.84,51.2711864407,25,3
# 324
# Naumanullah
# Naumanullah,1.0,0.0,4.0,100.0,1,0
# 325
# Tanvir Ahmed
# Tanvir Ahmed,3.0,0.0,18.0,150.0,1,2
# 326
# Younis Khan
# Younis Khan,2.64655172414,0.215517241379,28.5,73.2712765957,116,4
# 327
# Wahab Riaz
# Wahab Riaz,1.29166666667,0.0416666666667,10.9791666667,79.1291291291,48,1
# 328
# AB Barath
# AB Barath,2.76923076923,0.0769230769231,21.6153846154,56.4257028112,13,3
# 329
# MN van Wyk
# MN van Wyk,3.33333333333,0.266666666667,27.2,66.9950738916,15,4
# 330
# WW Hinds
# WW Hinds,1.11111111111,0.0,12.0,38.9891696751,9,3
# 331
# F du Plessis
# F du Plessis,3.4512195122,0.292682926829,34.9268292683,83.1349782293,82,4
# 332
# WU Tharanga
# WU Tharanga,3.93984962406,0.263157894737,32.969924812,71.6035271065,133,4
# 333
# SM Warnapura
# SM Warnapura,2.0,0.0,15.0,46.875,2,3
# 334
# Imran Tahir
# Imran Tahir,0.625,0.0,5.0625,65.8536585366,16,1
# 335
# AN Petersen
# AN Petersen,3.11111111111,0.222222222222,27.6666666667,81.6393442623,18,4
# 336
# AC Botha
# AC Botha,1.25,0.0833333333333,14.3333333333,53.75,12,3
# 337
# DG Brownlie
# DG Brownlie,3.0,0.0,22.5555555556,72.5,9,1
# 338
# S Badrinath
# S Badrinath,0.666666666667,0.0,13.1666666667,45.6647398844,6,3
# 339
# V Permaul
# V Permaul,0.333333333333,0.0,3.66666666667,50.0,3,3
# 340
# MA Carberry
# MA Carberry,2.8,0.2,22.6,63.4831460674,5,1
# 341
# NL McCullum
# NL McCullum,1.6393442623,0.0655737704918,17.3770491803,85.6219709208,61,0
# 342
# M Ntini
# M Ntini,0.375,0.0,3.25,63.4146341463,16,1
# 343
# AG Cremer
# AG Cremer,0.766666666667,0.0,10.5,54.6875,30,3
# 344
# A Flintoff
# A Flintoff,2.4375,0.09375,22.5,86.5384615385,32,4
# 345
# J Charles
# J Charles,3.82352941176,0.147058823529,28.2352941176,81.2182741117,34,4
# 346
# Mahbubul Alam
# Mahbubul Alam,3.5,0.5,39.5,109.722222222,2,0
# 347
# G Gambhir
# G Gambhir,3.99145299145,0.333333333333,37.4700854701,84.1943537546,117,4
# 348
# NJ Astle
# NJ Astle,2.8,0.1,20.0,67.5675675676,10,1
# 349
# Faisal Iqbal
# Faisal Iqbal,3.0,0.0,26.0,53.0612244898,1,3
# 350
# Sarfraz Ahmed
# Sarfraz Ahmed,2.0487804878,0.0975609756098,25.487804878,83.9357429719,41,4
# 351
# HM Nicholls
# HM Nicholls,2.625,0.25,26.875,73.883161512,8,4
# 352
# Anwar Ali
# Anwar Ali,2.14285714286,0.0,18.5714285714,82.2784810127,14,1
# 353
# S Chattergoon
# S Chattergoon,4.66666666667,0.166666666667,27.8333333333,60.9489051095,6,4
# 354
# Imad Wasim
# Imad Wasim,2.33333333333,0.333333333333,25.3333333333,90.4761904762,3,0
# 355
# BP Nash
# BP Nash,1.0,0.0,5.0,62.5,1,1
# 356
# CR Woakes
# CR Woakes,1.09375,0.0,15.15625,76.8621236133,32,1
# 357
# Naeem Islam
# Naeem Islam,1.88888888889,0.111111111111,18.6888888889,67.4959871589,45,1
# 358
# W Jaffer
# W Jaffer,1.0,0.0,5.0,43.4782608696,2,3
# 359
# Anamul Haque
# Anamul Haque,4.12,0.24,36.8,69.6442089326,25,4
# 360
# RS Morton
# RS Morton,2.2962962963,0.222222222222,28.8888888889,67.0103092784,27,4
# 361
# FH Edwards
# FH Edwards,0.384615384615,0.0,4.46153846154,50.4347826087,13,3
# 362
# M Muralitharan
# M Muralitharan,0.69696969697,0.0,5.63636363636,99.4652406417,33,0
# 363
# GS Ballance
# GS Ballance,1.69230769231,0.153846153846,22.0,66.3573085847,13,1
# 364
# R Dhawan
# R Dhawan,0.5,0.0,6.0,92.3076923077,2,0
# 365
# AF Milne
# AF Milne,1.0,0.0,11.5454545455,95.4887218045,11,0
# 366
# Sabbir Rahman
# Sabbir Rahman,3.23529411765,0.117647058824,25.6470588235,98.1981981982,17,0
# 367
# AB Dinda
# AB Dinda,0.2,0.0,4.2,55.2631578947,5,3
# 368
# R Clarke
# R Clarke,1.5,0.0,19.5,81.25,2,1
# 369
# JD Ryder
# JD Ryder,4.88571428571,0.257142857143,34.4,97.253634895,35,0
# 370
# IDR Bradshaw
# IDR Bradshaw,0.571428571429,0.0,7.14285714286,47.619047619,7,3
# 371
# MA Vermeulen
# MA Vermeulen,1.85714285714,0.142857142857,20.2857142857,68.2692307692,7,1
# 372
# MM Sharma
# MM Sharma,0.625,0.0,3.75,56.6037735849,8,3
# 373
# Shafiul Islam
# Shafiul Islam,0.535714285714,0.0,4.42857142857,57.6744186047,28,3
# 374
# GD Elliott
# GD Elliott,2.671875,0.203125,29.4375,79.7629127858,64,4
# 375
# MN Waller
# MN Waller,2.07894736842,0.0789473684211,19.3684210526,68.9784442362,38,1
# 376
# Shoaib Akhtar
# Shoaib Akhtar,0.421052631579,0.0,3.21052631579,67.032967033,19,1
# 377
# I Sharma
# I Sharma,0.24,0.0,2.84,34.1346153846,25,3
# 378
# MS Panesar
# MS Panesar,0.285714285714,0.0,3.71428571429,28.2608695652,7,3
# 379
# AJ Finch
# AJ Finch,4.52941176471,0.313725490196,37.2549019608,83.4431269214,51,4
# 380
# ML Hayden
# ML Hayden,6.37837837838,0.378378378378,50.6756756757,83.3333333333,37,4
# 381
# DPMD Jayawardene
# DPMD Jayawardene,3.20833333333,0.244791666667,31.6979166667,79.1108800208,192,4
# 382
# AR White
# AR White,1.17647058824,0.0,14.1764705882,59.9502487562,17,1
# 383
# C Zhuwao
# C Zhuwao,3.0,0.0,16.0,72.7272727273,1,1
# 384
# Shahid Afridi
# Shahid Afridi,2.72916666667,0.0972222222222,21.4097222222,127.766266059,144,0
# 385
# LL Tsotsobe
# LL Tsotsobe,0.444444444444,0.0,3.16666666667,50.8928571429,18,3
# 386
# BB Chari
# BB Chari,1.0,0.0,19.0,45.5089820359,4,3
# 387
# SP Fleming
# SP Fleming,3.875,0.25,30.2916666667,70.9268292683,24,4
# 388
# Zulfiqar Babar
# Zulfiqar Babar,0.6,0.0,7.0,87.5,5,0
# 389
# JJ Roy
# JJ Roy,4.36842105263,0.210526315789,29.3684210526,95.3846153846,19,0
# 390
# DW Steyn
# DW Steyn,0.75,0.0,6.52272727273,61.5879828326,44,1
# 391
# BJ Watling
# BJ Watling,3.0,0.263157894737,27.7894736842,66.9201520913,19,4
# 392
# Kamran Akmal
# Kamran Akmal,3.01123595506,0.112359550562,23.0786516854,81.4432989691,89,4
# 393
# CJ McKay
# CJ McKay,0.615384615385,0.0,6.88461538462,55.0769230769,26,3
# 394
# CRD Fernando
# CRD Fernando,0.571428571429,0.0,5.42857142857,64.7727272727,21,1
# 395
# SPD Smith
# SPD Smith,3.19298245614,0.228070175439,34.5614035088,87.0525850641,57,4
# 396
# ME Trescothick
# ME Trescothick,6.625,0.375,49.5,87.417218543,8,4
# 397
# JW Dernbach
# JW Dernbach,0.125,0.0,2.375,47.5,8,3
# 398
# C Munro
# C Munro,2.77777777778,0.222222222222,27.1111111111,93.1297709924,9,0
# 399
# MF Maharoof
# MF Maharoof,1.38888888889,0.0277777777778,14.3611111111,81.2893081761,36,1
# 400
# D Ramdin
# D Ramdin,1.74390243902,0.0975609756098,19.1951219512,81.1758638473,82,1
# 401
# DJG Sammy
# DJG Sammy,2.25,0.09,18.25,95.8005249344,100,0
# 402
# JE Taylor
# JE Taylor,0.903225806452,0.0,6.96774193548,83.3976833977,31,1
# 403
# JEC Franklin
# JEC Franklin,1.67307692308,0.0769230769231,18.7115384615,77.5298804781,52,1
# 404
# LJ Wright
# LJ Wright,1.92105263158,0.0263157894737,17.2368421053,81.875,38,1
# 405
# RR Rossouw
# RR Rossouw,3.80769230769,0.230769230769,31.3846153846,93.1506849315,26,0
# 406
# MS Atapattu
# MS Atapattu,2.63636363636,0.0,24.4545454545,66.9154228856,11,4
# 407
# Junaid Siddique
# Junaid Siddique,2.16279069767,0.116279069767,20.023255814,68.2250396197,43,1
# 408
# Liton Das
# Liton Das,1.0,0.0,7.66666666667,69.696969697,6,1
# 409
# MKDI Amerasinghe
# MKDI Amerasinghe,0.333333333333,0.0,1.66666666667,71.4285714286,3,1
# 410
# KAJ Roach
# KAJ Roach,0.526315789474,0.0,5.68421052632,50.5854800937,38,3
# 411
# Ehsan Adil
# Ehsan Adil,0.666666666667,0.0,7.33333333333,66.6666666667,3,1
# 412
# HH Dippenaar
# HH Dippenaar,1.8,0.2,22.0,54.1871921182,5,3
# 413
# GP Swann
# GP Swann,1.08695652174,0.0,10.3043478261,90.6309751434,46,0
# 414
# Adnan Akmal
# Adnan Akmal,0.75,0.0,15.25,66.3043478261,4,1
# 415
# Naved-ul-Hasan
# Naved-ul-Hasan,1.15,0.0,11.35,83.4558823529,20,1
# 416
# RS Bopara
# RS Bopara,2.22115384615,0.144230769231,25.1538461538,75.9361393324,104,4
# 417
# Mohammed Shami
# Mohammed Shami,0.684210526316,0.0,5.68421052632,88.5245901639,19,0
# 418
# Haris Sohail
# Haris Sohail,3.25,0.3,35.2,80.8266360505,20,4
# 419
# Shoaib Malik
# Shoaib Malik,2.77551020408,0.19387755102,28.7040816327,81.441806601,98,4
# 420
# Nasir Jamshed
# Nasir Jamshed,3.63043478261,0.239130434783,30.2173913043,73.8183749336,46,4
# 421
# Shuvagoto Hom
# Shuvagoto Hom,3.0,0.0,23.3333333333,79.5454545455,3,4
# 422
# RW Price
# RW Price,0.666666666667,0.0,7.16666666667,57.2062084257,36,3
# 423
# DC Thomas
# DC Thomas,1.11111111111,0.0,12.4444444444,61.3698630137,18,1
# 424
# MP Vaughan
# MP Vaughan,2.6,0.1,20.6,66.4516129032,10,1
# 425
# WD Parnell
# WD Parnell,1.47826086957,0.0434782608696,15.8260869565,74.7433264887,23,1
# 426
# TT Bresnan
# TT Bresnan,1.52380952381,0.015873015873,13.8095238095,88.4146341463,63,0
# 427
# MS Wade
# MS Wade,1.86274509804,0.117647058824,20.3333333333,78.2641509434,51,1
# 428
# CK Langeveldt
# CK Langeveldt,0.571428571429,0.0,4.71428571429,59.4594594595,14,3
# 429
# DAJ Bracewell
# DAJ Bracewell,0.428571428571,0.0,8.42857142857,65.5555555556,7,1
# 430
# KD Mills
# KD Mills,1.52542372881,0.0338983050847,12.8644067797,90.7894736842,59,0
# 431
# UT Yadav
# UT Yadav,0.533333333333,0.0,3.46666666667,56.5217391304,15,3
# 432
# Dolar Mahmud
# Dolar Mahmud,2.33333333333,0.0,13.6666666667,117.142857143,3,0
# 433
# JWM Dalrymple
# JWM Dalrymple,1.41666666667,0.0833333333333,19.0,73.786407767,24,1
# 434
# KMDN Kulasekara
# KMDN Kulasekara,1.21,0.04,11.8,80.9327846365,100,1
# 435
# K Weeraratne
# K Weeraratne,1.5,0.0,19.0,97.4358974359,2,0
# 436
# UT Khawaja
# UT Khawaja,2.8,0.2,21.6,84.375,5,4
# 437
# Suhrawadi Shuvo
# Suhrawadi Shuvo,1.0,0.0,9.7,70.2898550725,10,1
# 438
# RR Sarwan
# RR Sarwan,2.8253968254,0.222222222222,29.1428571429,69.1004892736,63,4
# 439
# CA Pujara
# CA Pujara,0.5,0.0,6.0,34.7826086957,4,3
# 440
# WB Rankin
# WB Rankin,0.0833333333333,0.0,3.08333333333,35.9223300971,12,3
# 441
# Arafat Sunny
# Arafat Sunny,0.5,0.0,4.7,50.0,10,3
# 442
# Q de Kock
# Q de Kock,5.12962962963,0.240740740741,39.1111111111,91.2311015119,54,4
# 443
# Yasir Hameed
# Yasir Hameed,1.2,0.2,28.2,51.2727272727,5,3
# 444
# MJ Prior
# MJ Prior,2.27083333333,0.0625,21.6875,76.4878765614,48,4
# 445
# TMK Mawoyo
# TMK Mawoyo,0.571428571429,0.0,8.28571428571,34.9397590361,7,3
# 446
# J Botha
# J Botha,1.09756097561,0.0,11.5609756098,82.2916666667,41,1
# 447
# DA Miller
# DA Miller,2.57352941176,0.132352941176,24.9411764706,97.247706422,68,0
# 448
# RT Ponting
# RT Ponting,4.17431192661,0.339449541284,38.1009174312,80.8605919003,109,4
# 449
# Zafar Gohar
# Zafar Gohar,1.0,0.0,15.0,100.0,1,0
# 450
# Yasir Arafat
# Yasir Arafat,2.66666666667,0.0,17.3333333333,58.4269662921,3,3
# 451
# MJ Clarke
# MJ Clarke,3.10294117647,0.301470588235,35.9264705882,74.0303030303,136,4
# 452
# Habibul Bashar
# Habibul Bashar,1.125,0.0,15.25,51.2605042017,16,3
# 453
# GH Dockrell
# GH Dockrell,0.875,0.0,9.0625,69.7115384615,16,1
# 454
# GJ Maxwell
# GJ Maxwell,3.79245283019,0.22641509434,28.2264150943,119.68,53,0
# 455
# RJ Nicol
# RJ Nicol,3.3,0.2,29.25,73.400250941,20,4
# 456
# RJ Peterson
# RJ Peterson,1.62068965517,0.0344827586207,15.7931034483,83.5766423358,29,1
# 457
# MA Starc
# MA Starc,0.692307692308,0.0,8.46153846154,70.0636942675,13,1
# 458
# MR Marsh
# MR Marsh,3.61538461538,0.269230769231,32.2307692308,95.3356086462,26,0
# 459
# SJ Harmison
# SJ Harmison,0.142857142857,0.0,5.14285714286,72.0,7,1
# 460
# J Lewis
# J Lewis,0.571428571429,0.0,6.0,85.7142857143,7,1
# 461
# R Rampaul
# R Rampaul,1.30303030303,0.030303030303,9.90909090909,77.4881516588,33,1
# 462
# D Langford-Smith
# D Langford-Smith,0.888888888889,0.0,8.66666666667,92.8571428571,9,0
# 463
# BW Hilfenhaus
# BW Hilfenhaus,0.222222222222,0.0,3.22222222222,40.8450704225,9,3
# 464
# KD Karthik
# KD Karthik,2.46428571429,0.107142857143,21.6785714286,71.8768502072,56,1
# 465
# AG Prince
# AG Prince,1.14285714286,0.0,18.1428571429,76.5060240964,7,1
# 466
# PA Browne
# PA Browne,2.6,0.0,26.8,73.2240437158,5,4
# 467
# JM Anderson
# JM Anderson,0.365384615385,0.0,3.92307692308,52.7131782946,52,3
# 468
# RT Crandon
# RT Crandon,1.0,0.0,5.0,55.5555555556,1,3
# 469
# PA Nixon
# PA Nixon,1.35294117647,0.0,16.0,79.3002915452,17,1
# 470
# Mohammad Amir
# Mohammad Amir,1.5,0.0714285714286,12.0,73.6842105263,14,1
# 471
# S Randiv
# S Randiv,1.6875,0.0625,15.875,69.9724517906,16,1
# 472
# NM Lyon
# NM Lyon,0.666666666667,0.0,4.0,133.333333333,3,0
# 473
# TC Mutombodzi
# TC Mutombodzi,1.0,0.0,8.33333333333,96.1538461538,3,0
# 474
# JP Faulkner
# JP Faulkner,2.88235294118,0.147058823529,24.1470588235,109.612817089,34,0
# 475
# RN Lewis
# RN Lewis,1.66666666667,0.0,19.5,119.387755102,6,0
# 476
# JL Carter
# JL Carter,1.63636363636,0.0,14.7272727273,55.8620689655,11,3
# 477
# SR Clark
# SR Clark,0.285714285714,0.0,4.0,54.9019607843,7,3
# 478
# F Behardien
# F Behardien,2.0303030303,0.0909090909091,21.2424242424,91.3950456323,33,0
# 479
# P Mustard
# P Mustard,3.33333333333,0.111111111111,23.8888888889,88.1147540984,9,0
# 480
# A Mishra
# A Mishra,0.375,0.0,3.5,42.4242424242,8,3
# 481
# Nasir Hossain
# Nasir Hossain,2.75,0.159090909091,27.0454545455,79.386257505,44,4
# 482
# IG Butler
# IG Butler,1.14285714286,0.0,11.1428571429,62.9032258065,7,1
# 483
# TT Samaraweera
# TT Samaraweera,2.19230769231,0.0769230769231,23.4230769231,73.8181818182,26,4
# 484
# JS Patel
# JS Patel,0.7,0.0,8.4,60.0,10,3
# 485
# FDM Karunaratne
# FDM Karunaratne,0.8,0.0,10.7,64.8484848485,10,1
# 486
# SM Katich
# SM Katich,2.33333333333,0.0,18.6666666667,50.4504504505,3,3
# 487
# Misbah-ul-Haq
# Misbah-ul-Haq,2.95238095238,0.285714285714,34.9920634921,71.8195145789,126,4
# 488
# DBL Powell
# DBL Powell,0.529411764706,0.0,5.76470588235,77.1653543307,17,1
# 489
# LS Baker
# LS Baker,0.666666666667,0.0,3.33333333333,58.8235294118,3,3
# 490
# Shakib Al Hasan
# Shakib Al Hasan,2.86991869919,0.252032520325,29.9105691057,79.0163230241,123,4
# 491
# Shahriar Nafees
# Shahriar Nafees,3.40540540541,0.162162162162,24.4864864865,69.1075514874,37,4
# 492
# HJH Marshall
# HJH Marshall,1.1,0.1,11.4,69.512195122,10,1
# 493
# Javed Omar
# Javed Omar,2.66666666667,0.166666666667,24.3333333333,48.0263157895,6,3
# 494
# KS Williamson
# KS Williamson,4.31707317073,0.390243902439,43.0487804878,82.8833059404,82,4
# 495
# GA Lamb
# GA Lamb,0.333333333333,0.0,14.0833333333,46.174863388,12,3
# 496
# K Rabada
# K Rabada,1.0,0.0,8.0,64.8648648649,6,1
# 497
# Asad Ali
# Asad Ali,0.5,0.0,5.0,62.5,2,1
# 498
# LPC Silva
# LPC Silva,2.55555555556,0.244444444444,26.0222222222,69.4543297746,45,4
# 499
# P Utseya
# P Utseya,0.842105263158,0.0263157894737,11.8289473684,55.8385093168,76,3
# 500
# AJ Ireland
# AJ Ireland,0.2,0.0,2.2,17.7419354839,5,3
# 501
# KM Jarvis
# KM Jarvis,0.333333333333,0.0,3.75,36.2903225806,12,3
# 502
# GJ Hopkins
# GJ Hopkins,1.3125,0.0,14.75,74.4479495268,16,1
# 503
# AR Patel
# AR Patel,0.642857142857,0.0,6.14285714286,92.4731182796,14,0
# 504
# TL Chatara
# TL Chatara,0.705882352941,0.0,5.82352941176,57.225433526,17,3
# 505
# L Ronchi
# L Ronchi,2.92156862745,0.078431372549,22.1960784314,115.392456677,51,0
# 506
# WPUJC Vaas
# WPUJC Vaas,0.653846153846,0.0,8.65384615385,66.1764705882,26,1
# 507
# BJ Haddin
# BJ Haddin,3.14736842105,0.147368421053,26.7789473684,81.3819577735,95,4
# 508
# XJ Doherty
# XJ Doherty,0.190476190476,0.0,4.28571428571,52.0231213873,21,3
# 509
# AN Cook
# AN Cook,4.17045454545,0.272727272727,35.75,75.5523535062,88,4
# 510
# BC Lara
# BC Lara,3.35714285714,0.178571428571,29.3571428571,75.7603686636,28,4
# 511
# PJ Hughes
# PJ Hughes,4.52380952381,0.285714285714,38.7619047619,74.7474747475,21,4
# 512
# JF Mooney
# JF Mooney,1.47619047619,0.0,13.7619047619,72.7959697733,21,1
# 513
# PA Patel
# PA Patel,2.65217391304,0.130434782609,22.1304347826,79.4071762871,23,4
# 514
# A Mithun
# A Mithun,2.0,0.0,17.0,89.4736842105,3,0
# 515
# CJ Jordan
# CJ Jordan,0.833333333333,0.0,8.22222222222,84.0909090909,18,1
# 516
# Mohammad Sami
# Mohammad Sami,1.75,0.0,16.0,56.6371681416,4,3
# 517
# MB Loye
# MB Loye,3.42857142857,0.0,20.2857142857,74.7368421053,7,1
# 518
# BM Wheeler
# BM Wheeler,1.75,0.0,14.5,123.404255319,4,0
# 519
# Jubair Hossain
# Jubair Hossain,1.0,0.0,5.0,50.0,1,3
# 520
# T Taibu
# T Taibu,2.36363636364,0.254545454545,29.4,71.0144927536,55,4
# 521
# Litton Das
# Litton Das,2.66666666667,0.0,25.3333333333,72.380952381,3,4
# 522
# MD Bates
# MD Bates,2.0,0.0,9.0,90.0,1,0
# 523
# SMSM Senanayake
# SMSM Senanayake,1.0625,0.0,8.625,87.0662460568,32,1
# 524
# KTGD Prasad
# KTGD Prasad,1.33333333333,0.0,12.4444444444,106.666666667,9,0
# 525
# AM Ellis
# AM Ellis,1.0,0.0,12.75,80.9523809524,12,1
# 526
# AB de Villiers
# AB de Villiers,5.04968944099,0.403726708075,47.2173913043,98.8428032766,161,4
# 527
# A Nel
# A Nel,1.06666666667,0.0,7.66666666667,81.5602836879,15,1
# 528
# Aamer Yamin
# Aamer Yamin,4.5,0.5,31.0,84.9315068493,2,4
# 529
# JE Root
# JE Root,3.68852459016,0.327868852459,41.6721311475,83.3442622951,61,4
# 530
# LR Johnson
# LR Johnson,1.0,0.0,6.33333333333,29.2307692308,3,3
# 531
# GJ Batty
# GJ Batty,0.333333333333,0.0,7.33333333333,40.0,3,3
# 532
# Salman Butt
# Salman Butt,5.4358974359,0.384615384615,42.3846153846,78.8645038168,39,4
# 533
# DT Johnston
# DT Johnston,1.27272727273,0.0,12.1818181818,74.2382271468,22,1
# 534
# BV Vitori
# BV Vitori,0.9,0.0,6.3,86.301369863,10,1
# 535
# TM Dilshan
# TM Dilshan,4.60199004975,0.273631840796,38.3631840796,86.0218652387,201,4
# 536
# KJ O'Brien
# KJ O'Brien,2.64705882353,0.0588235294118,22.3823529412,79.4363256785,34,4
# 537
# RG Sharma
# RG Sharma,3.82835820896,0.268656716418,35.9179104478,83.0830312446,134,4
# 538
# Iftikhar Ahmed
# Iftikhar Ahmed,0.5,0.0,4.0,25.8064516129,2,3
# 539
# DR Flynn
# DR Flynn,2.0,0.0,16.7,67.6113360324,10,1
# 540
# Sami Aslam
# Sami Aslam,7.0,0.0,44.0,84.6153846154,1,4
# 541
# A Nehra
# A Nehra,0.263157894737,0.0,2.84210526316,43.2,19,3
# 542
# Harbhajan Singh
# Harbhajan Singh,0.901639344262,0.0,9.98360655738,76.4115432873,61,1
# 543
# KDK Vithanage
# KDK Vithanage,1.83333333333,0.0,12.3333333333,80.4347826087,6,1
# 544
# Umar Amin
# Umar Amin,2.14285714286,0.0714285714286,18.8571428571,67.3469387755,14,1
# 545
# JO Holder
# JO Holder,2.13636363636,0.0909090909091,16.9090909091,97.8947368421,22,0
# 546
# SS Pathirana
# SS Pathirana,2.33333333333,0.0,21.6666666667,85.5263157895,3,4
# 547
# Umar Akmal
# Umar Akmal,2.76842105263,0.2,27.5052631579,82.7946768061,95,4
# 548
# M Kaif
# M Kaif,1.77777777778,0.222222222222,23.8888888889,61.4285714286,9,1
# 549
# MH Yardy
# MH Yardy,0.875,0.0833333333333,13.5833333333,66.5306122449,24,1
# 550
# Sohail Khan
# Sohail Khan,0.333333333333,0.0,4.16666666667,48.0769230769,6,3
# 551
# PJ Cummins
# PJ Cummins,0.571428571429,0.0,4.85714285714,53.9682539683,7,3
# 552
# JC Tredwell
# JC Tredwell,0.52,0.0,6.52,65.991902834,25,1
# 553
# Imrul Kayes
# Imrul Kayes,3.0,0.207547169811,26.2641509434,63.6488340192,53,4
# 554
# MN Samuels
# MN Samuels,3.74757281553,0.233009708738,31.6213592233,74.58209297,103,4
# 555
# VS Solanki
# VS Solanki,2.0,0.0,27.0,101.886792453,2,0
# 556
# MK Pandey
# MK Pandey,5.0,0.666666666667,59.6666666667,101.704545455,3,4
# 557
# SF Mire
# SF Mire,2.11111111111,0.222222222222,21.0,65.625,9,1
# 558
# AD Hales
# AD Hales,4.2962962963,0.296296296296,34.1111111111,85.1201478743,27,4
# 559
# STR Binny
# STR Binny,2.4,0.1,20.5,95.7943925234,10,0
# 560
# Dhiman Ghosh
# Dhiman Ghosh,0.909090909091,0.0,11.2727272727,60.487804878,11,1
# 561
# TJ Murtagh
# TJ Murtagh,1.0,0.0,8.2,93.1818181818,5,0
# 562
# T Kamungozi
# T Kamungozi,0.555555555556,0.0,2.77777777778,44.6428571429,9,3
# 563
# DR Smith
# DR Smith,2.5,0.12,17.96,84.5574387947,50,1
# 564
# BB McCullum
# BB McCullum,3.98611111111,0.201388888889,29.9027777778,98.4003656307,144,0
# 565
# AB Agarkar
# AB Agarkar,0.3125,0.0,5.75,44.6601941748,16,3
# 566
# SK Raina
# SK Raina,3.11111111111,0.216374269006,28.9064327485,91.8944041643,171,0
# 567
# BA Stokes
# BA Stokes,2.23529411765,0.117647058824,20.1470588235,90.0131406045,34,0
# 568
# S Sreesanth
# S Sreesanth,0.125,0.0,2.4375,32.5,16,3
# 569
# P Kumar
# P Kumar,1.0,0.03125,9.03125,86.0119047619,32,1
# 570
# OA Shah
# OA Shah,3.13043478261,0.239130434783,32.6739130435,81.1993517018,46,4
# 571
# JL Ontong
# JL Ontong,2.66666666667,0.0,22.3333333333,76.1363636364,3,4
# 572
# Azhar Ali
# Azhar Ali,3.83333333333,0.3,38.5333333333,73.6775015934,30,4
# 573
# V Kohli
# V Kohli,4.66455696203,0.379746835443,44.9936708861,88.3325049702,158,4
# 574
# SE Findlay
# SE Findlay,2.75,0.25,22.0,62.8571428571,4,1
# 575
# WP Saha
# WP Saha,0.75,0.0,6.0,64.8648648649,4,1

# %%
data[432], kresult[432]
# Out:
# ({'Batsman': 'Dolar Mahmud',
#   'Batting Average': 13.6666666667,
#   'Home Run Hitting Ability': 2.33333333333,
#   'Matches Played': 3,
#   'Milestone Reaching Ability': 0.0,
#   'Strike Rate': 117.142857143},
#  {'cluster_id': 0, 'distance': 18.3256893157959, 'row_id': 432})

# %%
data[792], kresult[792]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-53cdb3d083e7> in <module>()
# ----> 1 data[792], kresult[792]
#
# /home/laxmikant/anaconda/lib/python2.7/site-packages/graphlab/data_structures/sframe.pyc in __getitem__(self, key)
#    3565                 key = sf_len + key
#    3566             if key >= sf_len:
# -> 3567                 raise IndexError("SFrame index out of range")
#    3568
#    3569             if not hasattr(self, '_cache') or self._cache is None:
#
# IndexError: SFrame index out of range

# %%
data[259], kresult[259]
# Out:
# ({'Batsman': 'RP Arnold',
#   'Batting Average': 16.4285714286,
#   'Home Run Hitting Ability': 1.14285714286,
#   'Matches Played': 14,
#   'Milestone Reaching Ability': 0.142857142857,
#   'Strike Rate': 73.2484076433},
#  {'cluster_id': 1, 'distance': 4.05819034576416, 'row_id': 259})

# %%
data[175], kresult[175]
# Out:
# ({'Batsman': 'B Geeves',
#   'Batting Average': 10.0,
#   'Home Run Hitting Ability': 1.0,
#   'Matches Played': 1,
#   'Milestone Reaching Ability': 0.0,
#   'Strike Rate': 90.9090909091},
#  {'cluster_id': 0, 'distance': 12.13586139678955, 'row_id': 175})

# %%
data[149], kresult[149]
# Out:
# ({'Batsman': 'JC Buttler',
#   'Batting Average': 29.9152542373,
#   'Home Run Hitting Ability': 3.47457627119,
#   'Matches Played': 59,
#   'Milestone Reaching Ability': 0.186440677966,
#   'Strike Rate': 115.359477124},
#  {'cluster_id': 0, 'distance': 19.596065521240234, 'row_id': 149})

# %%
data[786], kresult[786]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-cf3dc5248342> in <module>()
# ----> 1 data[786], kresult[786]
#
# /home/laxmikant/anaconda/lib/python2.7/site-packages/graphlab/data_structures/sframe.pyc in __getitem__(self, key)
#    3565                 key = sf_len + key
#    3566             if key >= sf_len:
# -> 3567                 raise IndexError("SFrame index out of range")
#    3568
#    3569             if not hasattr(self, '_cache') or self._cache is None:
#
# IndexError: SFrame index out of range

# %%
data[511], kresult[511]
# Out:
# ({'Batsman': 'PJ Hughes',
#   'Batting Average': 38.7619047619,
#   'Home Run Hitting Ability': 4.52380952381,
#   'Matches Played': 21,
#   'Milestone Reaching Ability': 0.285714285714,
#   'Strike Rate': 74.7474747475},
#  {'cluster_id': 4, 'distance': 7.909668922424316, 'row_id': 511})

# %%
data[519], kresult[519]
# Out:
# ({'Batsman': 'Jubair Hossain',
#   'Batting Average': 5.0,
#   'Home Run Hitting Ability': 1.0,
#   'Matches Played': 1,
#   'Milestone Reaching Ability': 0.0,
#   'Strike Rate': 50.0},
#  {'cluster_id': 3, 'distance': 3.4874134063720703, 'row_id': 519})

# %%
data[759], kresult[759]
# Out:
# ({'Batsman': 'M Kaif',
#   'Batting Average': 23.8888888889,
#   'Home Run Hitting Ability': 1.77777777778,
#   'Matches Played': 9,
#   'Milestone Reaching Ability': 0.222222222222,
#   'Strike Rate': 61.4285714286},
#  {'cluster_id': 1, 'distance': 6.461941719055176, 'row_id': 759})

# %%
data[295], kresult[295]
# Out:
# ({'Batsman': 'R Ashwin',
#   'Batting Average': 11.9454545455,
#   'Home Run Hitting Ability': 1.16363636364,
#   'Matches Played': 55,
#   'Milestone Reaching Ability': 0.0181818181818,
#   'Strike Rate': 84.7741935484},
#  {'cluster_id': 4, 'distance': 1.8154319524765015, 'row_id': 295})
