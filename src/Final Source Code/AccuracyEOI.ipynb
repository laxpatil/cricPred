# %%
import graphlab as gl

# %%
data= gl.SFrame('Dat/Inn2-StartSeg5-HR_NHR-10.csv')
# Out:
# Finished parsing file /home/laxmikant/cricPred/src/Dat/Inn2-StartSeg5-HR_NHR-10.csv
# Parsing completed. Parsed 100 lines in 0.010187 secs.
# Finished parsing file /home/laxmikant/cricPred/src/Dat/Inn2-StartSeg5-HR_NHR-10.csv
# Parsing completed. Parsed 234 lines in 0.007758 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,int,float,float,float,float,float,float,int,str,int,int,int,int,float,int,float,int,float,float,int,int,int,int,int,float,float,float,float,int,int,int,float,int,float,float,float,float,float,int,float,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------

# %%
data
# Out:
# Columns:
# 	Team	str
# 	Total Matches Played	int
# 	Runs Scored	float
# 	Wickets Lost	float
# 	Got All Out	float
# 	Runs Conceded	float
# 	Opponent Wickets Taken	float
# 	Opponent All Out	float
# 	Match Index	int
# 	Batsman	str
# 	Player Total Runs	int
# 	Player Home Runs	int
# 	Player Non Home Runs	int
# 	Balls Faced	int
# 	R0	float
# 	W0	int
# 	R1	float
# 	W1	int
# 	Current_HR	float
# 	Current_NHR	float
# 	Target	int
# 	Final Runs Made	int
# 	Extras	int
# 	Home	int
# 	Segment	int
# 	Home Run Hitting Ability	float
# 	Milestone Reaching Ability	float
# 	Batting Average	float
# 	Strike Rate	float
# 	Matches Played	int
# 	ClusterID	int
# 	Actual Total HR till Segment	int
# 	Predicted Total HR till Segment	float
# 	Actual Total NHR till Segment	int
# 	Predicted Total NHR till Segment	float
# 	Actual HR in Segment	float
# 	Predicted HR in Segment	float
# 	Actual NHR in Segment	float
# 	Predicted NHR in Segment	float
# 	Actual Total Runs till Segment	int
# ...

# %%
acc=data[ ( (data["Predicted Total Runs till Segment"] > data["Opponent Runs"] \
             and data["Target"] > data['Final Runs Made']) or \
           (data["Predicted Total Runs till Segment"] < data["Opponent Runs"] \
             and data["Target"] <  data["Final Runs Made"]) )] \

# %%
len(acc), len(data)
# Out:
# (139, 234)
